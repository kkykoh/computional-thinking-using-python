# %% [markdown]
# ## Class Exercise 1 -- Python Basics

# %% [markdown]
# ### Variables

# %%
# Variable definition and assignment
a = 1
b = 'Hello World'
c = True

# Access variable
print(a)
print(b)
print(c)
# Out:
# 1
# Hello World
# True

# %%
a, b = 1, 2
print(a + b)
print('a' + 'b')  # concats strings a & b
print('1' + '2')
# Out:
# 3
# ab
# 12

# %% [markdown]
# ### Comments

# %%
# This is a single-line comment
print('Hello World')
# Out:
# Hello World

# %%
''' This is a multi-line comment
xxx
yyy
''' # this is not returned because it is not the last thing that you told python
print('Hello World') # this is returned cause it is the last line
# Out:
# Hello World

# %%
print('Hello World')
''' This is a multi-line comment 
xxx
yyy
'''
# it returns hello world cause of the print
# returns the multi-line comment is because 
# it is python returning the last line 
# (aka python returning the last thing you told it)

# %%
'abd'
'def' # python returns the last thing you told

# %%
""" This is also a multi-line comment
xxx
yyy"""
print('Hello World')
# Out:
# Hello World

# %%
print('Hello World')
""" This is also a multi-line comment
xxx
yyy"""

# %%
print('Hello World') # You can add the comment after the command
# Out:
# Hello World

# %%
# print('Hello World')

# %% [markdown]
# ### Basic data types

# %%
a = True
print(type(a))
print(a)
# Out:
# <class 'bool'>
# True

# %%
a = 20
print(type(a))
print(a)
# Out:
# <class 'int'>
# 20

# %%
a = 20.21
print(type(a))
print(a)
# Out:
# <class 'float'>
# 20.21

# %%
a = 'the "art" of programming'
print(type(a))
print(a)
# Out:
# <class 'str'>
# the "art" of programming

# %%
# check the quotation marks
a = "the 'art' of programming"
print(type(a))
print(a)
# Out:
# <class 'str'>
# the 'art' of programming

# %%
d = 'this is a 'good' day' 

# the good is treated as a var
# and the front and back are treated as 2 strings

# so if you need to change it to  either one below
d = "this is a 'good' day"
d = 'this is a "good" day'

# %%
# prefix with 0b
bin(True)

# bin() converts from boolean to binary
# true = 1
# Out:
# '0b1'

# %%
bin(False)

# bin() converts from boolean to binary
# false = 0
# Out:
# '0b0'

# %%
bin(3)

# number : binary form
# 0  :  0
# 1  :  1
# 2  :  10
# 3  :  11
# 4  :  100
# Out:
# '0b11'

# %%
# 12345
#                 (base 10)
#     5  
#    40   <-- 4 * (10**1)
#   300   <-- 3 * (10**2)
#  2000   <-- 2 * (10**3)
# 10000   <-- 1 * (10**4)

# %%
bin(8)

# binary 1000

# 8    <--- 1*base*3    where base=2 (think mathetically)
# Out:
# '0b1000'

# %%
int ('z', 36)

int('10', 36) # 10 here is binary
#   1       < -- 1 * (base**1) = 1 * 36

int ('20', 36 ) #20 here is binary
#   2       < -- 2 * (base**1) = 2 * 36

int('d00', 36) # where d is binary
#   2       < -- 2 * (base**1) = 2 * 36

# %%
print('100' < '23') # true because 2 > 1

print(int(100) < int(23)) #false becayse they are numbers

print('100'*23 < '23' * 46) # true because as long as the leading 1 < 2, then it will always been true


# Capital letters have a smaller ascii than small letters
print ('ab' < 'AB') # false because 'a' has a larger ascii than 'A' (97 vs 65)

print('12' < 'AB') # true becuase number is smaller than letters

# %% [markdown]
# #### Type casting

# %%
int(-1.99)
# Out:
# -1

# %%
int('dog', 36)
# Out:
# 17728

# %%
int('d', 36), int('o', 36), int('g', 36)
# Out:
# (13, 24, 16)

# %%
13 * 36 ** 2 + 24 * 36 ** 1 + 16 * 36 **0
# Out:
# 17728

# %%
int('thequickbrownfoxjumpsoverthelazydog', 36)
# Out:
# 2420279590275804445606588463955072096420804747701564608

# %%
float('0.999999999999999999999999999999999999')
# Out:
# 1.0

# %%
float('-inf')
# Out:
# -inf

# %%
str(0.987654321)
# Out:
# '0.987654321'

# %%
bool(-1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# #### String encoding

# %%
# Covert a character to a number
ord('a')
# Out:
# 97

# %%
bin(97)

# %%
ord('A')
# Out:
# 65

# %%
# Covert a number to a character
chr(97)
# Out:
# 'a'

# %% [markdown]
# ### Python operators

# %% [markdown]
# #### Arithmetic operators

# %%
n = 5 + 3
n
# Out:
# 8

# %%
m = 5
m
# Out:
# 5

# %%
m += 3
m
# Out:
# 8

# %%
m += 10
print(m)

# %%
m **= 2
print(m)

# %%
m //= 2
print(m)

# %%
# can use to concat strings 
mystring = 'qwe'

mystring += 'rty' # mystring = mystring + 'rty'

print(mystring)

# %%
5 / 3
# Out:
# 1.6666666666666667

# %%
5 // 3
# Out:
# 1

# %%
5 % 3
# Out:
# 2

# %%
-7 % 3
# Out:
# 2

# %%
5 ** 3
# Out:
# 125

# %%
5 / 300000
# Out:
# 1.6666666666666667e-05

# %%
5e3
# Out:
# 5000.0

# %% [markdown]
# #### Logical operators

# %%
not False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False or True
# Out:
# True

# %% [markdown]
# #### Assignment operators

# %%
i = 0
i += 1
print(i)
# Out:
# 1

# %%
i = 5
i %= 3
print(i)
# Out:
# 2

# %%
i = 2
i **= 3
print(i)
# Out:
# 8

# %% [markdown]
# #### Comparison operators

# %%
1 < 2
# Out:
# True

# %%
1.01 < 1
# Out:
# False

# %%
a = True
b = False
a > b
# Out:
# True

# %%
a = 'a'
b = 'A'
a < b
# Out:
# False

# %%
ord('a'), ord('A')
# Out:
# (97, 65)

# %%
ord(' ')
# Out:
# 32

# %%
c = 'a '
a < c
# Out:
# True

# %%
ord('b')
# Out:
# 98

# %%
d = 'ab'
d < c
# Out:
# False

# %%
e = 'b '
e < d
# Out:
# False

# %% [markdown]
# #### String operators

# %%
'news' + 'paper' + 'man'
# Out:
# 'newspaperman'

# %%
s = 'eigen'
s += 'value'
s
# Out:
# 'eigenvalue'

# %%
'-' * 10
# Out:
# '----------'

# %%
s = 'machine learning'
len(s)
# Out:
# 16

# %%
s[2]
# Out:
# 'c'

# %%
print(s[5:10])
# Out:
# ne le

# %%
print(s[8:])
print(s[8:100])
# Out:
# learning
# learning

# %%
print(s[:7])
print(s[0:7])
# Out:
# machine
# machine

# %%
print(s[-7])
print(s[-7:-3])
# Out:
# e
# earn

# %%
print(s[9:-3])
# Out:
# earn

# %%
print(s[-7:13])
# Out:
# earn

# %%
print(s[5:10:2])
# Out:
# n e

# %%
print(s[5:10:3])
# Out:
# nl

# %%
print(s[9:4:-2])
# Out:
# e n

# %%
s.find('a')
# Out:
# 1

# %%
s.find('a', 4)
# Out:
# 10

# %%
s.find('a', 4, 10)
# Out:
# -1

# %%
s.rfind('a')
# Out:
# 10

# %%
s.rfind('a', 4)
# Out:
# 10

# %%
s.rfind('a', 4, 10)
# Out:
# -1

# %%
print(1234, 567.89)
print("usually next line")
# Out:
# 1234 567.89
# usually next line

# %%
print(1234, 567.89, sep = '-', end = '#')
print("usually next line")
# Out:
# 1234-567.89#usually next line

# %%
print('Program name: {} \nCourse name: {} \nCourse code: {}'.format('MITB', 'CT with Python', 'IS628'))
# Out:
# Program name: MITB
# Course name: CT with Python
# Course code: IS628

# %%
print('Program name: {1} \nCourse name: {0} \nCourse code: {2}'.format('MITB', 'CT with Python', 'IS628'))
# Out:
# Program name: CT with Python
# Course name: MITB
# Course code: IS628

# %%
print('Program name: {program} \nCourse name: {course} \nCourse code: {id}'.format(course = 'CT with Python', id = 'IS628', program = 'MITB'))
# Out:
# Program name: MITB
# Course name: CT with Python
# Course code: IS628

# %%
print('{:s} is approximately {:03d}/{:<2d} = {:.2f}'.format('pi', 22, 7, 3.1415926))
# Out:
# pi is approximately 022/7  = 3.14

# %%
print('{0:s} is approximately {1:^5d}/{2:^5d} = {3:.6f}'.format('pi', 355, 113, 3.1415926))
# Out:
# pi is approximately  355 / 113  = 3.141593

# %% [markdown]
# ### Conditionals

# %% [markdown]
# #### if and elif

# %%
i = int(input())
if i % 2 == 0:
    print('this is an even number')
else:
    print('this is an odd number')
# Out:
#  5
# this is an odd number

# %%
i = int(input())
if i % 2 == 0:
    print('this is an even number')
elif i % 3 == 0:
    print('this is a multiple of 3')
else:
    print('this is a prime number')
# Out:
#  9
# this is a multiple of 3

# %% [markdown]
# ### Exercise 1: Calculate BMI

# %% [markdown]
# Body Mass Index is a simple calculation using a person’s height and weight. The formula is $BMI = kg/m^2$ where $kg$ is a person’s weight in kilograms and $m^2$ is their height in metres squared. </br>
# A BMI of 25.0 or more is overweight, while the healthy range is 18.5 to 24.9. </br>
# Write a bmi calculator to understand your bmi weight status.

# %%
weight =  # Input your dream weight
height = # Input your dream height
# Out:
# Input your dream weight: 45
# Input your dream height: 1.6
# Underweight

# %% [markdown]
# ### Exercise 2: Calculate Carbon

# %% [markdown]
# When you execute a heavy computational workload in the cloud, you may notice that the final environmental impact exceeds the raw energy used by the CPU. This is primarily due to two environmental multipliers: Grid Carbon Intensity and the data center's Power Usage Effectiveness (PUE). While the server's base energy is simply its hardware power (kW) multiplied by its runtime (hours), the PUE typically adds a 20% overhead for facility cooling. Some unoptimized codebases even impose an "inefficient algorithm penalty" that drastically increases the total runtime.
#
# There are two types of cloud regions you can deploy to:
#
# 1. Clean Region
# 2. Standard Region
#
# You also need to speficy if the "Inefficient Algorithm Penalty" is to be applied.
#
# Write a carbon footprint calculator for estimating the actual emissions.

# %%
power = float(input("Enter server hardware power in kW (e.g., 0.15 for 150W): "))
runtime = float(input("Enter base script runtime in hours (e.g., 1.5): "))
region = input("Select region type (1 or 2): ")
inefficient_surcharge = input("Apply Inefficient Algorithm Penalty? (Y/N): ")

pue = 0.2
clean = 0.030     # kg CO2/kWh
standard = 0.450  # kg CO2/kWh
inefficient = 10
        

print("Total emissions is {:.4f} kg CO2".format(total_emissions))
# Out:
# Enter server hardware power in kW (e.g., 0.15 for 150W):  0.15
# Enter base script runtime in hours (e.g., 1.5):  1.5
# Select region type (1 or 2):  1
# Apply Inefficient Algorithm Penalty? (Y/N):  Y

# %% [markdown]
# ### Exercise 3: Shorten a Word

# %% [markdown]
# Letters between the first and last letters of a word may be replaced by the number of letters omitted. </br>
# For example, the word "internationalization" can be abbreviated by replacing the eighteen middle letters ("nternationalizatio") with "18", leaving "i18n". </br>
# These word shortenings are sometimes called numerical contractions. </br>
# Examples of numerical contractions include:
# - g11n: globalization
# - i14y – interoperability
# - a11y – accessibility
# - p13n – personalization
# - s5n – shorten
# - l10n – localization
# - i18n – internationalization
#
# Write a generator to help generate the numerical contractions.

# %%
word = input()
# Out:
#  localization
# l10n
