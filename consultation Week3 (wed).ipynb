# %%
a = 2
b = 0
c = -2
print(a < 0 or (b > 0 and c < 0))

#   False            (    False      )
# Out:
# False

# %%
a = 3
b = 3
c = -3
print(a > 0 and not (b > 0 or c > 0))
# Out:
# False

# %%
int(5/2)

# decimal places (eg, 2.5, 1.75) will be rounded down

int(7/4)
# Out:
# 1

# %%
name = "Abcde"
res = name[0]
p = len(name)
mid = int(p / 2)
res += name[mid] + name[p-1]   ## what if we used negative indices?
# res = res + name[mid] + name[p-1]
#        A       c           e
print(res)
# Out:
# Ace

# %%
name = "Abcdef"
res = name[0]
p = len(name)
mid = int(p / 2)   # int(6/2) = 3
res += name[mid] + name[p-1]
print(res)
# Out:
# Adf

# %%
len(s)
# Out:
# 10

# %%
# s[-1]
s[9]

# %%
# s[0:-1:-2]
s[0:9:-2]

# %%
s = "university"
# s[-1::-2]   # start at -1, interval -2

# s[0:-1:-2] 
print(s[0:-1:-2] + "see")

# returns an empty string because you start at the point that ends 
# nothing further you can go 
# should not even return the u

s[3:8:2]   # s[3]+s[5]+s[7]
# Out:
# see
# 'vri'

# %%
for i in range(8,2,3):
    print(i)

# %%
s

# %%
# s[8:5]
for i in range(8,5):
    print(i)

# %%
print('a', 'bc')  # print('a', 'bc', sep=' ', end='\n')
print('d', 'efg')

# %%
print('a', 'bc', sep=' ', end='\n')
print('d', 'efg', sep=' ', end='\n')

# %%
s = 'pqr '

# print(s*2, 'xyz', sep='a')
print(s*2, 'xyz', sep='a', end='b')

# %%
for i in range(5):
    print('Hi', end='+')

# %%
'100' < '2'*2   # '22'

# %%
# 'x ' < 'xo'
'x ' < 'x'

# %%
d = {'a': 4, 'b': 2, 'c': 3, 'd': 1}
for k, v in d.items():
    if v % 2 == 0:
        v = v - 2
    else:
        d[k] = 4
print(d)

# %%
mylist = [5, 10, 12, 15, 20]

for x in mylist:
    x = 1
    print(x)

# %%
mylist

# %%
for i in range(len(mylist)):
    mylist[i] = 0

mylist
